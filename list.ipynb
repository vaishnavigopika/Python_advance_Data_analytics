# %%
a=[1,2,3,4]
print(a)
# Out:
# [1, 2, 3, 4]

# %%
mini=10000
pin=input("enter your PIN")
ch='y'
if (len(pin)==4):
    while(ch=='y'):
        print("1.Withdraw \n 2.Enquiry/n3.Exit")
        n=int(input("Enter your choice "))
        if(n==1):
            amt=int(input("Enter the amount to be withdrawen"))
            mini=mini-amt
            
        elif(n==2):
            print("Your current Balance is ",mini)
            
        elif n==3:
            ch=input("y/n")
        
        else:
            print("CHOICE NOT FOUND")
        
else:
    print("INVALID PIN")
# Out:
# 1.Withdraw
#  2.Enquiry/n3.Exit
# 1.Withdraw
#  2.Enquiry/n3.Exit
# Your current Balance is  9500
# 1.Withdraw
#  2.Enquiry/n3.Exit
# CHOICE NOT FOUND
# 1.Withdraw
#  2.Enquiry/n3.Exit

# %%
import csv
data = {}
with open('DS.csv', 'r') as file:
    csvFile = csv.reader(file)
    headers = next(csvFile) 
    for h in headers:
        data[h] = []
    for row in csvFile:
        for i in range(len(headers)):
            data[headers[i]].append(row[i])

print(data)
# Out:
# {'Name': ['Sri', 'Gautham', 'James'], 'Salary': ['10', '20', '30'], 'Capable': ['0', '1', '1']}

# %%
a= int(input("enter a string"))
s=0
s=s+a
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a= int(input("enter a string"))
#       2 s=0
#       3 s=s+a
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
    a= int(input("enter a string"))
    s=0
    s=s+a
    print(s)
except ValueError:
    print("Invalid input. Please enter a valid integer.")
# Out:
# Invalid input. Please enter a valid integer.
